# %%
#Use to import pandas
import pandas as pd
#Use to import the file into google Colab drive
from google.colab import files 
#Use to import io, which opens the file from the Colab drive
import io
from google.colab import files

# %%
# Upload files from enrichment_analysis folder
uploaded = files.upload()
uploaded1 = files.upload()
uploaded2 = files.upload()
uploaded3 = files.upload()
uploaded4 = files.upload()
# Out:
#      <input type="file" id="files-5a67832d-1f7a-4b69-b8a1-3ba0594409f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a67832d-1f7a-4b69-b8a1-3ba0594409f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ranked_decile.csv to ranked_decile.csv
#      <input type="file" id="files-8a9789c6-6515-4989-860b-d201ab25a4f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a9789c6-6515-4989-860b-d201ab25a4f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ranked_full.csv to ranked_full.csv
# ...

# %%
# Upload into dataframes and sanity check
df = pd.read_csv(io.StringIO(uploaded['ranked_decile.csv'].decode('utf-8')))
df1 = pd.read_csv(io.StringIO(uploaded1['ranked_full.csv'].decode('utf-8')))
df2 = pd.read_csv(io.StringIO(uploaded2['ranked_top10.csv'].decode('utf-8')))
df3 = pd.read_csv(io.StringIO(uploaded3['hpa_intersect1.csv'].decode('utf-8')))
df4 = pd.read_csv(io.StringIO(uploaded4['hpa_intersect2.csv'].decode('utf-8')))

# %%
# Top decile of results
df
# Out:
#       Unnamed: 0             myID         0         1
# 0            242  ENSG00000184009  0.006835  0.993165
# 1           2270  ENSG00000070831  0.014067  0.985933
# 2           9997  ENSG00000081237  0.014217  0.985783
# 3           6973  ENSG00000188906  0.016984  0.983016
# 4           2978  ENSG00000118260  0.020948  0.979052
# ...          ...              ...       ...       ...
# 1402       10751  ENSG00000105193  0.265692  0.734308
# 1403       13160  ENSG00000162341  0.265698  0.734302
# 1404        5179  ENSG00000113384  0.265888  0.734112
# 1405        7748  ENSG00000110079  0.265908  0.734092
# 1406        7615  ENSG00000196199  0.266063  0.733937
#
# [1407 rows x 4 columns]

# %%
# Full list of results
df1
# Out:
#        Unnamed: 0             myID         0         1
# 0             242  ENSG00000184009  0.006835  0.993165
# 1            2270  ENSG00000070831  0.014067  0.985933
# 2            9997  ENSG00000081237  0.014217  0.985783
# 3            6973  ENSG00000188906  0.016984  0.983016
# 4            2978  ENSG00000118260  0.020948  0.979052
# ...           ...              ...       ...       ...
# 14071        7071  ENSG00000003056  0.997730  0.002270
# 14072        8118  ENSG00000003509  0.997824  0.002176
# 14073        2567  ENSG00000033100  0.997999  0.002001
# 14074        1234  ENSG00000027847  0.999134  0.000866
# 14075       10065  ENSG00000011478  0.999247  0.000753
#
# [14076 rows x 4 columns]

# %%
# Top 10 genes
df2
# Out:
#    Unnamed: 0             myID         0         1
# 0         242  ENSG00000184009  0.006835  0.993165
# 1        2270  ENSG00000070831  0.014067  0.985933
# 2        9997  ENSG00000081237  0.014217  0.985783
# 3        6973  ENSG00000188906  0.016984  0.983016
# 4        2978  ENSG00000118260  0.020948  0.979052
# 5        8041  ENSG00000149294  0.022346  0.977654
# 6        7895  ENSG00000172936  0.022673  0.977326
# 7        6186  ENSG00000187608  0.022868  0.977132
# 8        4838  ENSG00000010810  0.025687  0.974313
# 9        6219  ENSG00000150093  0.025800  0.974200

# %%
# Check 0.01 gda score threshold dataframe
df3
# Out:
#          Gene  Score_gda  EI_gda          ensembl
# 0         ADA       0.02     1.0  ENSG00000196839
# 1        CDH3       0.01     1.0  ENSG00000062038
# 2       HDAC6       0.01     1.0  ENSG00000094631
# 3       PDCD6       0.01     1.0  ENSG00000249915
# 4     BCL2L11       0.04     1.0  ENSG00000153094
# ...       ...        ...     ...              ...
# 1750     MFN2       0.03     1.0  ENSG00000116688
# 1751    KIF14       0.01     1.0  ENSG00000118193
# 1752   P2RY14       0.01     1.0  ENSG00000174944
# 1753      MVP       0.03     1.0  ENSG00000013364
# 1754     CDH1       0.23     1.0  ENSG00000039068
#
# [1755 rows x 4 columns]

# %%
# Change 'ensemble' column to myID to enable you to merge with oher dataframes
df_3 = df3.rename(columns={'ensembl': 'myID'})
df_3
# Out:
#          Gene  Score_gda  EI_gda             myID
# 0         ADA       0.02     1.0  ENSG00000196839
# 1        CDH3       0.01     1.0  ENSG00000062038
# 2       HDAC6       0.01     1.0  ENSG00000094631
# 3       PDCD6       0.01     1.0  ENSG00000249915
# 4     BCL2L11       0.04     1.0  ENSG00000153094
# ...       ...        ...     ...              ...
# 1750     MFN2       0.03     1.0  ENSG00000116688
# 1751    KIF14       0.01     1.0  ENSG00000118193
# 1752   P2RY14       0.01     1.0  ENSG00000174944
# 1753      MVP       0.03     1.0  ENSG00000013364
# 1754     CDH1       0.23     1.0  ENSG00000039068
#
# [1755 rows x 4 columns]

# %%
# Check 0.02 gda score threshold dataframe
df4
# Out:
#             Gene  Score_gda  EI_gda          ensembl
# 0            ADA       0.02     1.0  ENSG00000196839
# 1        BCL2L11       0.04     1.0  ENSG00000153094
# 2          SH2B3       0.10     1.0  ENSG00000111252
# 3    COMMD3-BMI1       0.06     1.0  ENSG00000269897
# 4    MSH5-SAPCD1       0.10     1.0  ENSG00000204410
# ..           ...        ...     ...              ...
# 773         ZEB2       0.04     1.0  ENSG00000169554
# 774        CDC20       0.03     1.0  ENSG00000117399
# 775         MFN2       0.03     1.0  ENSG00000116688
# 776          MVP       0.03     1.0  ENSG00000013364
# 777         CDH1       0.23     1.0  ENSG00000039068
#
# [778 rows x 4 columns]

# %%
# Change 'ensemble' column to myID to enable you to merge with oher dataframes
df_4 = df4.rename(columns={'ensembl': 'myID'})
df_4
# Out:
#             Gene  Score_gda  EI_gda             myID
# 0            ADA       0.02     1.0  ENSG00000196839
# 1        BCL2L11       0.04     1.0  ENSG00000153094
# 2          SH2B3       0.10     1.0  ENSG00000111252
# 3    COMMD3-BMI1       0.06     1.0  ENSG00000269897
# 4    MSH5-SAPCD1       0.10     1.0  ENSG00000204410
# ..           ...        ...     ...              ...
# 773         ZEB2       0.04     1.0  ENSG00000169554
# 774        CDC20       0.03     1.0  ENSG00000117399
# 775         MFN2       0.03     1.0  ENSG00000116688
# 776          MVP       0.03     1.0  ENSG00000013364
# 777         CDH1       0.23     1.0  ENSG00000039068
#
# [778 rows x 4 columns]

# %%
# Check intersection between top decile of gene results and 0.02 gda threshold list
enrichment_intersect_dec2 = pd.merge(df, df_4, how='inner')
enrichment_intersect_dec2
# As we see, there is no intersection because the 0.02 gda score threshold genes were inputs to the model. Thus, they are excluded from this output
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, myID, 0, 1, Gene, Score_gda, EI_gda]
# Index: []

# %%
# Check intersection between top decile of gene results and 0.01 gda threshold list
enrichment_intersect_dec1 = pd.merge(df, df_3, how='inner')
enrichment_intersect_dec1
# Out:
#      Unnamed: 0             myID         0         1   Gene  Score_gda  EI_gda
# 0          9997  ENSG00000081237  0.014217  0.985783  PTPRC       0.01     1.0
# 1          6973  ENSG00000188906  0.016984  0.983016  LRRK2       0.01     1.0
# 2          2978  ENSG00000118260  0.020948  0.979052  CREB1       0.01     1.0
# 3          8041  ENSG00000149294  0.022346  0.977654  NCAM1       0.01     1.0
# 4          7895  ENSG00000172936  0.022673  0.977326  MYD88       0.01     1.0
# ..          ...              ...       ...       ...    ...        ...     ...
# 288        6294  ENSG00000130522  0.260745  0.739255   JUND       0.01     1.0
# 289        4813  ENSG00000089280  0.260918  0.739082    FUS       0.01     1.0
# 290        2233  ENSG00000110848  0.261260  0.738740   CD69       0.01     1.0
# 291       12626  ENSG00000160180  0.263600  0.736400   TFF3       0.01     1.0
# 292         303  ENSG00000160710  0.263996  0.736004   ADAR       0.01     1.0
#
# [293 rows x 7 columns]

# %%
# Check intersection between full gene results and 0.02 gda threshold list
enrichment_intersect_full2 = df.merge(df_4, how='inner')
enrichment_intersect_full2
# As we see, there is no intersection because the 0.02 gda score threshold genes were inputs to the model. Thus, they are excluded from this output
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, myID, 0, 1, Gene, Score_gda, EI_gda]
# Index: []

# %%
enrichment_intersect_full_1 = pd.merge(df1, df_3, how='inner')
enrichment_intersect_full_1
# Out:
#      Unnamed: 0             myID         0         1    Gene  Score_gda  EI_gda
# 0          9997  ENSG00000081237  0.014217  0.985783   PTPRC       0.01     1.0
# 1          6973  ENSG00000188906  0.016984  0.983016   LRRK2       0.01     1.0
# 2          2978  ENSG00000118260  0.020948  0.979052   CREB1       0.01     1.0
# 3          8041  ENSG00000149294  0.022346  0.977654   NCAM1       0.01     1.0
# 4          7895  ENSG00000172936  0.022673  0.977326   MYD88       0.01     1.0
# ..          ...              ...       ...       ...     ...        ...     ...
# 972        3301  ENSG00000011465  0.988178  0.011822     DCN       0.01     1.0
# 973         815  ENSG00000062725  0.990086  0.009914  APPBP2       0.01     1.0
# 974       10193  ENSG00000017797  0.992953  0.007047  RALBP1       0.01     1.0
# 975        2566  ENSG00000123989  0.993203  0.006797    CHPF       0.01     1.0
# 976        9865  ENSG00000059915  0.995823  0.004177     PSD       0.01     1.0
#
# ...

# %%
# Check intersection between top 10 results and 0.02 gda threshold list
enrichment_intersect_10_2 = pd.merge(df2, df_4, how='inner')
enrichment_intersect_10_2
# As we see, there is no intersection because the 0.02 gda score threshold genes were inputs to the model. Thus, they are excluded from this output
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, myID, 0, 1, Gene, Score_gda, EI_gda]
# Index: []

# %%
# Check intersection between top 10 results and 0.01 gda threshold list
enrichment_intersect_10_1 = pd.merge(df2, df_3, how='inner')
enrichment_intersect_10_1
# Out:
#    Unnamed: 0             myID         0         1   Gene  Score_gda  EI_gda
# 0        9997  ENSG00000081237  0.014217  0.985783  PTPRC       0.01     1.0
# 1        6973  ENSG00000188906  0.016984  0.983016  LRRK2       0.01     1.0
# 2        2978  ENSG00000118260  0.020948  0.979052  CREB1       0.01     1.0
# 3        8041  ENSG00000149294  0.022346  0.977654  NCAM1       0.01     1.0
# 4        7895  ENSG00000172936  0.022673  0.977326  MYD88       0.01     1.0
# 5        6219  ENSG00000150093  0.025800  0.974200  ITGB1       0.01     1.0

# %%
# Intersection between 0.01 and 0.02 threshold gda score
enrichment_intersect_1_2 = pd.merge(df_3, df_4, how='inner')
enrichment_intersect_1_2
# Out:
#             Gene  Score_gda  EI_gda             myID
# 0            ADA       0.02     1.0  ENSG00000196839
# 1        BCL2L11       0.04     1.0  ENSG00000153094
# 2          SH2B3       0.10     1.0  ENSG00000111252
# 3    COMMD3-BMI1       0.06     1.0  ENSG00000269897
# 4    MSH5-SAPCD1       0.10     1.0  ENSG00000204410
# ..           ...        ...     ...              ...
# 773         ZEB2       0.04     1.0  ENSG00000169554
# 774        CDC20       0.03     1.0  ENSG00000117399
# 775         MFN2       0.03     1.0  ENSG00000116688
# 776          MVP       0.03     1.0  ENSG00000013364
# 777         CDH1       0.23     1.0  ENSG00000039068
#
# [778 rows x 4 columns]

# %%
enrichmentfull_90_1 = enrichment_intersect_full_1[enrichment_intersect_full_1["1"] >= 0.90]
enrichmentfull_90_1
# Out:
#     Unnamed: 0             myID         0  ...      Gene Score_gda  EI_gda
# 0         9997  ENSG00000081237  0.014217  ...     PTPRC      0.01     1.0
# 1         6973  ENSG00000188906  0.016984  ...     LRRK2      0.01     1.0
# 2         2978  ENSG00000118260  0.020948  ...     CREB1      0.01     1.0
# 3         8041  ENSG00000149294  0.022346  ...     NCAM1      0.01     1.0
# 4         7895  ENSG00000172936  0.022673  ...     MYD88      0.01     1.0
# ..         ...              ...       ...  ...       ...       ...     ...
# 77       13065  ENSG00000067182  0.097047  ...  TNFRSF1A      0.01     1.0
# 78        7463  ENSG00000101752  0.097305  ...      MIB1      0.01     1.0
# 79       11270  ENSG00000118515  0.098438  ...      SGK1      0.01     1.0
# 80       10136  ENSG00000144566  0.098933  ...     RAB5A      0.01     1.0
# 81       13631  ENSG00000154277  0.099266  ...     UCHL1      0.01     1.0
#
# [82 rows x 7 columns]

# %%
# Import seaborn and matplotlib library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Check distribution of genes over 90% confidence
sns.displot(enrichmentfull_90_1, x="1", stat="count", bins=10)

# %%
# Check distribution of confidence results in bins of 10%
sns.displot(enrichment_intersect_full_1, x="1", stat="count", bins=10)

# %%
# To check and possibly upload each of the deciles
uploaded5 = files.upload()
uploaded6 = files.upload()
uploaded7 = files.upload()
uploaded8 = files.upload()
uploaded9 = files.upload()
uploaded10 = files.upload()
uploaded11 = files.upload()
uploaded12 = files.upload()
uploaded13 = files.upload()
uploaded14 = files.upload()
# Out:
#      <input type="file" id="files-ca10b4d8-59d8-4acf-a020-32af1ce7503a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca10b4d8-59d8-4acf-a020-32af1ce7503a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ranked_decile1.csv to ranked_decile1.csv
#      <input type="file" id="files-7414fd46-ff7f-4714-bb11-036d78e939c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7414fd46-ff7f-4714-bb11-036d78e939c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ranked_decile2.csv to ranked_decile2.csv
# ...

# %%
df5 = pd.read_csv(io.BytesIO(uploaded5['ranked_decile1.csv']))
df6 = pd.read_csv(io.BytesIO(uploaded6['ranked_decile2.csv']))
df7 = pd.read_csv(io.BytesIO(uploaded7['ranked_decile3.csv']))
df8= pd.read_csv(io.BytesIO(uploaded8['ranked_decile4.csv']))
df9 = pd.read_csv(io.BytesIO(uploaded9['ranked_decile5.csv']))
df10 = pd.read_csv(io.BytesIO(uploaded10['ranked_decile6.csv']))
df11 = pd.read_csv(io.BytesIO(uploaded11['ranked_decile7.csv']))
df12 = pd.read_csv(io.BytesIO(uploaded12['ranked_decile8.csv']))
df13 = pd.read_csv(io.BytesIO(uploaded13['ranked_decile9.csv']))
df14 = pd.read_csv(io.BytesIO(uploaded14['ranked_decile10.csv']))

# %%
# each decile list of ensembl genes
df5, df6, df7, df8, df9, df10, df11, df12, df13, df14
# Out:
# (      ENSG00000184009
#  0     ENSG00000070831
#  1     ENSG00000081237
#  2     ENSG00000188906
#  3     ENSG00000118260
#  4     ENSG00000149294
#  ...               ...
#  1401  ENSG00000105193
#  1402  ENSG00000162341
#  1403  ENSG00000113384
#  1404  ENSG00000110079
#  1405  ENSG00000196199
#
#  [1406 rows x 1 columns],       ENSG00000047410
#  0     ENSG00000132603
#  1     ENSG00000169925
#  2     ENSG00000128050
#  3     ENSG00000198087
#  4     ENSG00000143776
#  ...               ...
#  1401  ENSG00000187323
#  1402  ENSG00000135451
#  1403  ENSG00000122707
#  1404  ENSG00000110060
#  1405  ENSG00000167524
#
#  [1406 rows x 1 columns],       ENSG00000101751
#  0     ENSG00000115353
#  1     ENSG00000091136
#  2     ENSG00000164916
#  3     ENSG00000078098
#  4     ENSG00000087086
#  ...               ...
#  1401  ENSG00000127948
#  1402  ENSG00000101938
#  1403  ENSG00000205755
#  1404  ENSG00000068438
#  1405  ENSG00000171587
#
# ...
